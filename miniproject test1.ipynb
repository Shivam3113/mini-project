# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=['Yes','No','Sometimes']
y=[282,110,108]
plt.title("Aagrogya setu Access")
plt.bar(x,y,color=('red','yellow','blue'))
for i in range(len(x)):
    plt.text(i,y[i],y[i],ha="center",va='bottom')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
labels=['Yes','No','Sometimes']
values=[219,114,113]
colors=['y','r','b']
plt.title('Aagroya setu Access')
plt.pie(values,labels=labels,colors=colors,autopct='%2f%%')
plt.axis('equal')
# Out:
# (-1.1062744768763828,
#  1.100298784613161,
#  -1.1030653061939095,
#  1.107410921203983)

# %%
import matplotlib.pyplot as plt
labels=['yes','no']
values=[93,407]
colors=['r','b']
plt.title('covid 19 infected')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1045744320769912,
#  1.1002178405723035,
#  -1.1029547751739266,
#  1.1057949724695708)

# %%
x=['Male','Female','Others']
y=[283,216,1]
plt.bar(x,y)
for i in range(len(x)):
    plt.text(i,y[i],y[i],ha="center",va='bottom')
plt.title('GENDER')    
plt.
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
labels=['YES','NO']
values=[19,74]
colors=['g','b']
plt.title('Vacinated Before Infection')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1017010940881091,
#  1.1000810147173503,
#  -1.1010041765100946,
#  1.102481441098478)

# %%
import matplotlib.pyplot as plt
labels=['DIGITAL THERMOMETER','MERCURY THERMOMETER','OXIMETER','BP MACHINE','NONE']
values=[57,21,61,22,15]
colors=['r','b','y','g','c']
plt.title('monitoring instuments')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1173342145656764,
#  1.1008254387888416,
#  -1.1151275249885089,
#  1.1076448755056243)

# %%
import matplotlib.pyplot as plt
labels=['masks','sanitizers','face shields','PPE kits','Isolation gowns','none']
values=[79,80,25,11,8,5]
colors=['r','b','c','y','g','w']
plt.title('PREVENTIVE EQUIPMENTS')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1201023239223546,
#  1.1009572535201122,
#  -1.1159538415074397,
#  1.1213322019158438)

# %%
import matplotlib.pyplot as plt
labels=['males','females']
values=[224,293]
colors=['r','b','g']
plt.title('covid 19 infected')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1036892498492872,
#  1.1001756785642518,
#  -1.1108534376377113,
#  1.1275116122514246)

# %%
import matplotlib.pyplot as plt
labels=['above 60','below 20','bteween 20-30','between 30-40','between 40-60']
values=[13,55,281,35,117]
colors=['r','b','g','c','y']
plt.title('AGE GROUP')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1094300490567313,
#  1.1004490499550825,
#  -1.1028597968828984,
#  1.1113130847431143)

# %%
import matplotlib.pyplot as plt
labels=['NO','YES','SOMETIMES']
values=[114,219,113]
colors=['r','b','y']
plt.title('self assestments arogayasetu')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.101898714117162, 1.10009041495796, -1.1029239822724257, 1.104443118852825)

# %%
import numpy as np 
import matplotlib.pyplot as plt
y=['masks','social distancing','Avoid crowded places','Washing Hands Frequency']
w=[392,383,385,375]
plt.barh(y,w)
plt.xlabel('Number of people')
plt.ylabel('Methods used')
plt.title('MEASURES TAKEN FOR PREVENTION')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
labels=['NO','YES']
values=[300,107]
colors=['r','b']
plt.title('Vaccinated for non infr')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1180158335423598,
#  1.1008578968353504,
#  -1.1092142898896573,
#  1.119672970428167)

# %%
x=['5','4','3','2','1']
y=[108,136,123,20,20]
plt.bar(x,y)
for i in range(len(x)):
    plt.text(i,y[i],y[i],ha="center",va='bottom')
plt.title('RATING OF ALLOPATHY') 

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=['5','4','3','2','1']
y=[49,95,133,56,74]
plt.bar(x,y)
for i in range(len(x)):
    plt.text(i,y[i],y[i],ha="center",va='bottom')
plt.title('RATING OF HOMEOPATHY') 

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=['5','4','3','2','1']
y=[92,120,106,52,37]
plt.bar(x,y)
for i in range(len(x)):
    plt.text(i,y[i],y[i],ha="center",va='bottom')
plt.title('RATING OF AYURVEDIC') 

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
labels=['Digital Thermometer','Mercury Thermometer','BP Machine','Oxymeter','None']
values=[326,219,231,295,111]
colors=['r','b','y','g','m']
plt.title('MONITORING INSTRUMENTS PURCHASED BY NOT INFECTED')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.121193589307754,
#  1.1010092185384646,
#  -1.1345745856484717,
#  1.1124235853702242)

# %%
import matplotlib.pyplot as plt
labels=['Masks','Sanitizers','PPE Kits','Isolation Gowns','Face Shields']
values=[400,392,50,40,167]
colors=['r','b','y','g','m']
plt.title('PREVENTIVE EQUIPMENTS PURCHASED BY NOT INFECTED')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1195051512871477,
#  1.1009288167279594,
#  -1.106968188399577,
#  1.1209052209982102)

# %%
import matplotlib.pyplot as plt
labels=['Steamer','Nabolizers','Disinfectant Sprayer','Lung Exerciser','None']
values=[163,50,98,32,217]
colors=['r','b','y','g','m']
plt.title('MEDICAL EQUIPMENTS PURCHASED BY NOT INFECTED')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1174984752347643,
#  1.100833260725465,
#  -1.1207071583819361,
#  1.1120035734988973)

# %%
import matplotlib.pyplot as plt
labels=['Handwash','Sanitizers','Masks','Paracetamol Tab','None']
values=[235,270,271,215,102]
colors=['r','b','y','g','m']
plt.title('STOCKING  BY NOT INFECTED')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.135488486539652, 1.101689932731744, -1.1228691991571416, 1.13570672819809)

# %%
import matplotlib.pyplot as plt
labels=['Vitamins','Homeopathy medicine','Kadha','Turmeric Milk','Amala Juice','Coconut Water','None']
values=[297,164,289,296,206,221,0]
colors=['r','b','y','g','m','c','k']
plt.title('PDTS FOR IMMUNITY BOOSTING PURCHASED BY NOT INFECTED')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1107730350651879,
#  1.1005130171514081,
#  -1.1105350943834007,
#  1.105013645546848)

# %%
x=['Yes','No']
y=[300,107]
plt.title("KADHA PREFERENCE")
plt.bar(x,y,color=('red','yellow'))
for i in range(len(x)):
    plt.text(i,y[i],y[i],ha="center",va='bottom')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
labels=['Home made','Patanjali Kwath','Ayush Ministry','None','Other']
values=[293,39,37,85,9]
colors=['r','b','y','g','m']
plt.title('KIND OF KADHA PREFER BY NOT INFECTED')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1144421055032385, 1.100687719309678, -1.1033624849508148, 1.11072615830737)

# %%
import matplotlib.pyplot as plt
labels=['Kadha','Turmeric Milk','both','None']
values=[61,29,108,209]
colors=['r','b','y','g']
plt.title('READY TO DRINK PREFER BY NOT INFECTED')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1082289361215398,
#  1.1003918541010258,
#  -1.1055025430678154,
#  1.1094270895842306)

# %%
import matplotlib.pyplot as plt
labels=['Yoga','Exercise','pranayam','None']
values=[395,456,354,49]
colors=['r','b','y','m']
plt.title(' TYPE OF WORKOUT BY NOT INFECTED')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1038226620683522,
#  1.1001820405604017,
#  -1.1012964313582017,
#  1.111142065180124)

# %%
import matplotlib.pyplot as plt
labels=['yoga mats','dumbells','skipping rope','indoor cycle','Resistance Band','None']
values=[124,73,103,26,45,207]
colors=['r','b','y','g','m','c']
plt.title('FITNESS RELATED EQUIPMENTS PURCHASED BY NOT INFECTED')
plt.pie(values,labels=labels,colors=colors,autopct='%1.1f%%')
plt.axis('equal')
# Out:
# (-1.1160279663430686,
#  1.1007632411207886,
#  -1.1163391185780085,
#  1.1090280887736406)

# %%
x=['5','4','3','2','1']
y=[208,128,56,6,9]
plt.bar(x,y)
for i in range(len(x)):
    plt.text(i,y[i],y[i],ha="center",va='bottom')
plt.title('RATING FOR PREVENTIVE MEASURE') 

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=['5','4','3','2','1']
y=[207,121,61,8,10]
plt.bar(x,y)
for i in range(len(x)):
    plt.text(i,y[i],y[i],ha="center",va='bottom')
plt.title('RATING FOR VACCINATION DRIVE') 

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=['5','4','3','2','1']
y=[272,94,27,7,7]
plt.bar(x,y)
for i in range(len(x)):
    plt.text(i,y[i],y[i],ha="center",va='bottom')
plt.title('RATING FOR SOCIAL DISTANCING') 

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
